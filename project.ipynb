# %% [markdown]
# # DSCI 531 Project

# %% [markdown]
# ## All necessary imports

# %%
import pandas as pd

# %% [markdown]
# ## Read in all necessary data files

# %%
data_path = 'data/'
dropout_df = pd.read_csv(data_path + '4-Year Cohort Dropout Rate.csv')
dropout_df = dropout_df.loc[(dropout_df['LocationType'] == 'County') & (dropout_df['TimeFrame'] == 2014)]
dropout_df
# Out:
#     LocationType         Location  TimeFrame DataFormat  Data
# 10        County          Alameda       2014    Percent  0.11
# 16        County           Alpine       2014    Percent   LNE
# 22        County           Amador       2014    Percent   0.1
# 28        County            Butte       2014    Percent   0.1
# 34        County        Calaveras       2014    Percent  0.05
# 40        County           Colusa       2014    Percent  0.17
# 46        County     Contra Costa       2014    Percent  0.08
# 52        County        Del Norte       2014    Percent  0.11
# 58        County        El Dorado       2014    Percent  0.06
# 64        County           Fresno       2014    Percent  0.13
# 70        County            Glenn       2014    Percent   0.1
# 76        County         Humboldt       2014    Percent  0.11
# 82        County         Imperial       2014    Percent   0.1
# 88        County             Inyo       2014    Percent  0.44
# 94        County             Kern       2014    Percent  0.14
# 100       County            Kings       2014    Percent  0.15
# 106       County             Lake       2014    Percent  0.14
# 112       County           Lassen       2014    Percent  0.11
# 118       County      Los Angeles       2014    Percent  0.13
# 124       County           Madera       2014    Percent  0.14
# 130       County            Marin       2014    Percent  0.07
# 136       County         Mariposa       2014    Percent  0.04
# 142       County        Mendocino       2014    Percent  0.14
# 148       County           Merced       2014    Percent  0.11
# 154       County            Modoc       2014    Percent  0.05
# 160       County             Mono       2014    Percent  0.34
# 166       County         Monterey       2014    Percent  0.13
# 172       County             Napa       2014    Percent   0.1
# 178       County           Nevada       2014    Percent  0.35
# 184       County           Orange       2014    Percent  0.07
# 190       County           Placer       2014    Percent  0.05
# 196       County           Plumas       2014    Percent  0.11
# 202       County        Riverside       2014    Percent  0.09
# 208       County       Sacramento       2014    Percent  0.11
# 214       County       San Benito       2014    Percent  0.11
# 220       County   San Bernardino       2014    Percent  0.12
# 226       County        San Diego       2014    Percent   0.1
# 232       County    San Francisco       2014    Percent  0.47
# 238       County      San Joaquin       2014    Percent  0.13
# 244       County  San Luis Obispo       2014    Percent  0.06
# 250       County        San Mateo       2014    Percent  0.07
# 256       County    Santa Barbara       2014    Percent  0.11
# 262       County      Santa Clara       2014    Percent  0.11
# 268       County       Santa Cruz       2014    Percent  0.09
# 274       County           Shasta       2014    Percent   0.1
# 280       County           Sierra       2014    Percent  0.03
# 286       County         Siskiyou       2014    Percent  0.06
# 292       County           Solano       2014    Percent  0.11
# 298       County           Sonoma       2014    Percent  0.12
# 304       County       Stanislaus       2014    Percent  0.11
# 310       County           Sutter       2014    Percent  0.11
# 316       County           Tehama       2014    Percent  0.13
# 322       County          Trinity       2014    Percent  0.05
# 328       County           Tulare       2014    Percent  0.13
# 334       County         Tuolumne       2014    Percent  0.12
# 340       County          Ventura       2014    Percent  0.09
# 346       County             Yolo       2014    Percent  0.09
# 352       County             Yuba       2014    Percent  0.15

# %%
income_df = pd.read_csv(data_path + 'Average Family Income (Median Income).csv')
income_df = income_df.loc[(income_df['LocationType'] == 'County') & (income_df['TimeFrame'] == 2014)]
income_df
# Out:
#     LocationType         Location  TimeFrame DataFormat    Data
# 11        County          Alameda       2014   Currency   91206
# 16        County           Alpine       2014   Currency     NaN
# 22        County           Amador       2014   Currency     LNE
# 28        County        Calaveras       2014   Currency     LNE
# 34        County           Colusa       2014   Currency   47625
# 40        County     Contra Costa       2014   Currency   96240
# 46        County        Del Norte       2014   Currency     LNE
# 52        County        El Dorado       2014   Currency   87858
# 58        County            Glenn       2014   Currency     LNE
# 64        County         Imperial       2014   Currency   44680
# 70        County             Inyo       2014   Currency   65394
# 76        County             Kern       2014   Currency   44701
# 82        County           Lassen       2014   Currency   67986
# 88        County           Madera       2014   Currency   41210
# 94        County            Marin       2014   Currency  124186
# 100       County         Mariposa       2014   Currency     LNE
# 106       County        Mendocino       2014   Currency   43449
# 112       County           Merced       2014   Currency   40552
# 117       County            Modoc       2014   Currency     NaN
# 123       County             Mono       2014   Currency     LNE
# 129       County             Napa       2014   Currency   74169
# 135       County           Placer       2014   Currency   91681
# 141       County           Plumas       2014   Currency     LNE
# 147       County        Riverside       2014   Currency   58493
# 153       County       San Benito       2014   Currency   68482
# 159       County   San Bernardino       2014   Currency   52961
# 165       County      San Joaquin       2014   Currency   51983
# 171       County  San Luis Obispo       2014   Currency   67253
# 177       County        San Mateo       2014   Currency  115812
# 183       County    Santa Barbara       2014   Currency   63404
# 189       County      Santa Clara       2014   Currency  113780
# 195       County           Shasta       2014   Currency   48965
# 201       County         Siskiyou       2014   Currency   36250
# 207       County           Solano       2014   Currency   67397
# 213       County           Sonoma       2014   Currency   68372
# 219       County       Stanislaus       2014   Currency   48257
# 225       County           Sutter       2014   Currency   54052
# 231       County           Tehama       2014   Currency   45320
# 237       County           Tulare       2014   Currency   37271
# 243       County         Tuolumne       2014   Currency   54809
# 249       County          Ventura       2014   Currency   83048
# 255       County             Yolo       2014   Currency   71130
# 261       County             Yuba       2014   Currency   46601

# %%
poverty_df = pd.read_csv(data_path + 'Children Living in Poverty.csv')
poverty_df = poverty_df.loc[(poverty_df['LocationType'] == 'County') & (poverty_df['TimeFrame'] == 2014)]
poverty_df
# Out:
#     LocationType         Location  TimeFrame DataFormat   Data
# 6         County          Alameda       2014    Percent  0.158
# 13        County           Alpine       2014    Percent  0.097
# 16        County           Amador       2014    Percent  0.218
# 23        County            Butte       2014    Percent  0.245
# 26        County        Calaveras       2014    Percent  0.118
# 32        County           Colusa       2014    Percent  0.207
# 36        County     Contra Costa       2014    Percent  0.139
# 43        County        Del Norte       2014    Percent  0.296
# 46        County        El Dorado       2014    Percent  0.123
# 53        County           Fresno       2014    Percent  0.391
# 56        County            Glenn       2014    Percent  0.252
# 63        County         Humboldt       2014    Percent  0.234
# 66        County         Imperial       2014    Percent  0.313
# 73        County             Inyo       2014    Percent  0.178
# 76        County             Kern       2014    Percent  0.329
# 83        County            Kings       2014    Percent  0.331
# 86        County             Lake       2014    Percent  0.334
# 93        County           Lassen       2014    Percent  0.235
# 96        County      Los Angeles       2014    Percent  0.260
# 103       County           Madera       2014    Percent  0.329
# 106       County            Marin       2014    Percent  0.108
# 113       County         Mariposa       2014    Percent  0.238
# 116       County        Mendocino       2014    Percent  0.284
# 123       County           Merced       2014    Percent  0.362
# 126       County            Modoc       2014    Percent  0.293
# 133       County             Mono       2014    Percent  0.055
# 136       County         Monterey       2014    Percent  0.256
# 143       County             Napa       2014    Percent  0.140
# 146       County           Nevada       2014    Percent  0.179
# 153       County           Orange       2014    Percent  0.176
# 156       County           Placer       2014    Percent  0.112
# 163       County           Plumas       2014    Percent  0.205
# 166       County        Riverside       2014    Percent  0.234
# 173       County       Sacramento       2014    Percent  0.249
# 176       County       San Benito       2014    Percent  0.166
# 183       County   San Bernardino       2014    Percent  0.264
# 186       County        San Diego       2014    Percent  0.188
# 193       County    San Francisco       2014    Percent  0.127
# 196       County      San Joaquin       2014    Percent  0.264
# 203       County  San Luis Obispo       2014    Percent  0.150
# 206       County        San Mateo       2014    Percent  0.095
# 213       County    Santa Barbara       2014    Percent  0.213
# 216       County      Santa Clara       2014    Percent  0.117
# 222       County       Santa Cruz       2014    Percent  0.172
# 226       County           Shasta       2014    Percent  0.239
# 232       County           Sierra       2014    Percent  0.273
# 237       County         Siskiyou       2014    Percent  0.303
# 242       County           Solano       2014    Percent  0.186
# 247       County           Sonoma       2014    Percent  0.151
# 252       County       Stanislaus       2014    Percent  0.283
# 257       County           Sutter       2014    Percent  0.228
# 262       County           Tehama       2014    Percent  0.260
# 267       County          Trinity       2014    Percent  0.252
# 272       County           Tulare       2014    Percent  0.373
# 277       County         Tuolumne       2014    Percent  0.177
# 282       County          Ventura       2014    Percent  0.162
# 287       County             Yolo       2014    Percent  0.190
# 293       County             Yuba       2014    Percent  0.302

# %%
dental_df = pd.read_csv(data_path + 'Children Who Have Annual Dental Visits.csv')
dental_df = dental_df.loc[(dental_df['LocationType'] == 'County') & (dental_df['TimeFrame'] == 2014)]
dental_df
# Out:
#      LocationType Location Age group  TimeFrame DataFormat     Data
# 8          County  Alameda       0-3       2014    Percent  0.54967
# 9          County  Alameda       4-5       2014    Percent  0.62094
# 10         County  Alameda       6-8       2014    Percent  0.62964
# 11         County  Alameda      9-11       2014    Percent  0.58512
# 12         County  Alameda     12-14       2014    Percent  0.52690
# ...           ...      ...       ...        ...        ...      ...
# 1379       County     Yuba      9-11       2014    Percent  0.59574
# 1380       County     Yuba     12-14       2014    Percent  0.52800
# 1381       County     Yuba     15-18       2014    Percent  0.44368
# 1382       County     Yuba     19-20       2014    Percent  0.30396
# 1383       County     Yuba      0-20       2014    Percent  0.50249
#
# [464 rows x 6 columns]

# %%
math_df = pd.read_csv(data_path + 'Percentage of 10th Graders Who Passed the CAHSEE Math Section.csv')
math_df = math_df.loc[(math_df['LocationType'] == 'County') & (math_df['TimeFrame'] == 2014)]
math_df
# Out:
#     LocationType         Location  TimeFrame DataFormat  Data
# 12        County          Alameda       2014    Percent  0.85
# 35        County           Alpine       2014    Percent   LNE
# 36        County           Amador       2014    Percent   0.9
# 59        County            Butte       2014    Percent  0.87
# 61        County        Calaveras       2014    Percent   0.9
# 83        County           Colusa       2014    Percent  0.79
# 85        County     Contra Costa       2014    Percent  0.86
# 106       County        Del Norte       2014    Percent  0.74
# 109       County        El Dorado       2014    Percent  0.92
# 130       County           Fresno       2014    Percent  0.81
# 133       County            Glenn       2014    Percent  0.82
# 154       County         Humboldt       2014    Percent  0.86
# 157       County         Imperial       2014    Percent  0.81
# 178       County             Inyo       2014    Percent  0.72
# 181       County             Kern       2014    Percent  0.82
# 202       County            Kings       2014    Percent  0.79
# 204       County             Lake       2014    Percent  0.73
# 227       County           Lassen       2014    Percent  0.85
# 228       County      Los Angeles       2014    Percent  0.84
# 251       County           Madera       2014    Percent  0.77
# 252       County            Marin       2014    Percent   0.9
# 275       County         Mariposa       2014    Percent  0.87
# 276       County        Mendocino       2014    Percent  0.79
# 299       County           Merced       2014    Percent  0.81
# 300       County            Modoc       2014    Percent  0.72
# 323       County             Mono       2014    Percent   0.8
# 324       County         Monterey       2014    Percent   0.8
# 347       County             Napa       2014    Percent  0.87
# 348       County           Nevada       2014    Percent   0.9
# 371       County           Orange       2014    Percent   0.9
# 372       County           Placer       2014    Percent  0.94
# 395       County           Plumas       2014    Percent  0.88
# 396       County        Riverside       2014    Percent  0.85
# 419       County       Sacramento       2014    Percent  0.83
# 420       County       San Benito       2014    Percent   0.8
# 443       County   San Bernardino       2014    Percent  0.83
# 444       County        San Diego       2014    Percent  0.88
# 467       County    San Francisco       2014    Percent  0.83
# 468       County      San Joaquin       2014    Percent  0.83
# 491       County  San Luis Obispo       2014    Percent  0.89
# 492       County        San Mateo       2014    Percent  0.88
# 515       County    Santa Barbara       2014    Percent  0.84
# 516       County      Santa Clara       2014    Percent  0.89
# 539       County       Santa Cruz       2014    Percent  0.83
# 540       County           Shasta       2014    Percent  0.87
# 563       County           Sierra       2014    Percent  0.94
# 564       County         Siskiyou       2014    Percent   0.9
# 587       County           Solano       2014    Percent  0.84
# 588       County           Sonoma       2014    Percent  0.87
# 611       County       Stanislaus       2014    Percent  0.82
# 612       County           Sutter       2014    Percent  0.86
# 635       County           Tehama       2014    Percent  0.81
# 636       County          Trinity       2014    Percent  0.83
# 659       County           Tulare       2014    Percent  0.82
# 660       County         Tuolumne       2014    Percent  0.85
# 683       County          Ventura       2014    Percent  0.86
# 684       County             Yolo       2014    Percent  0.87
# 706       County             Yuba       2014    Percent  0.79

# %%
abuse_df = pd.read_csv(data_path + 'Rate of Child Abuse (per 1,000).csv')
abuse_df = abuse_df.loc[(abuse_df['LocationType'] == 'County') & (abuse_df['TimeFrame'] == 2014)]
abuse_df
# Out:
#     LocationType         Location  TimeFrame DataFormat  Data
# 16        County          Alameda       2014       Rate   2.4
# 46        County           Alpine       2014       Rate   0.0
# 48        County           Amador       2014       Rate  14.8
# 78        County            Butte       2014       Rate  12.9
# 80        County        Calaveras       2014       Rate  22.5
# 110       County           Colusa       2014       Rate   6.3
# 112       County     Contra Costa       2014       Rate   5.2
# 142       County        Del Norte       2014       Rate  21.7
# 144       County        El Dorado       2014       Rate  11.0
# 174       County           Fresno       2014       Rate   9.1
# 176       County            Glenn       2014       Rate  12.4
# 206       County         Humboldt       2014       Rate  10.8
# 208       County         Imperial       2014       Rate  10.6
# 238       County             Inyo       2014       Rate  10.1
# 240       County             Kern       2014       Rate  14.8
# 270       County            Kings       2014       Rate  11.0
# 272       County             Lake       2014       Rate   6.6
# 302       County           Lassen       2014       Rate  18.2
# 304       County      Los Angeles       2014       Rate  11.6
# 334       County           Madera       2014       Rate   9.1
# 336       County            Marin       2014       Rate   4.0
# 366       County         Mariposa       2014       Rate   6.5
# 368       County        Mendocino       2014       Rate  18.7
# 398       County           Merced       2014       Rate   7.8
# 400       County            Modoc       2014       Rate  32.9
# 430       County             Mono       2014       Rate   8.9
# 432       County         Monterey       2014       Rate   3.8
# 462       County             Napa       2014       Rate   8.1
# 464       County           Nevada       2014       Rate   4.2
# 494       County           Orange       2014       Rate   7.7
# 496       County           Placer       2014       Rate   8.4
# 526       County           Plumas       2014       Rate  22.1
# 528       County        Riverside       2014       Rate  11.1
# 558       County       Sacramento       2014       Rate  11.7
# 560       County       San Benito       2014       Rate   5.0
# 590       County   San Bernardino       2014       Rate   9.0
# 592       County        San Diego       2014       Rate   7.2
# 622       County    San Francisco       2014       Rate   6.9
# 624       County      San Joaquin       2014       Rate   7.7
# 654       County  San Luis Obispo       2014       Rate  10.1
# 656       County        San Mateo       2014       Rate   2.5
# 686       County    Santa Barbara       2014       Rate   6.2
# 688       County      Santa Clara       2014       Rate   4.8
# 718       County       Santa Cruz       2014       Rate   6.8
# 720       County           Shasta       2014       Rate  13.1
# 750       County           Sierra       2014       Rate  18.9
# 752       County         Siskiyou       2014       Rate  17.3
# 782       County           Solano       2014       Rate   4.2
# 784       County           Sonoma       2014       Rate   4.5
# 814       County       Stanislaus       2014       Rate  14.9
# 816       County           Sutter       2014       Rate   5.0
# 846       County           Tehama       2014       Rate  14.3
# 848       County          Trinity       2014       Rate  34.4
# 878       County           Tulare       2014       Rate   8.2
# 880       County         Tuolumne       2014       Rate  20.2
# 910       County          Ventura       2014       Rate   6.3
# 912       County             Yolo       2014       Rate   8.7
# 942       County             Yuba       2014       Rate  12.8

# %%
df = pd.read_csv(data_path + 'Rate of Children in Foster Care (per 1,000).csv')
abuse_df = abuse_df.loc[(abuse_df['LocationType'] == 'County') & (abuse_df['TimeFrame'] == 2014)]
abuse_df
# Out:
#     LocationType    Location  TimeFrame DataFormat  Data
# 0          State  California       2000       Rate  11.0
# 1          State  California       2001       Rate  10.0
# 2          State  California       2002       Rate   9.4
# 3          State  California       2003       Rate   8.8
# 4          State  California       2004       Rate   8.3
# ..           ...         ...        ...        ...   ...
# 880       County        Yuba       2010       Rate   5.8
# 881       County        Yuba       2011       Rate   5.3
# 882       County        Yuba       2012       Rate   5.2
# 883       County        Yuba       2013       Rate   6.5
# 884       County        Yuba       2014       Rate   7.9
#
# [885 rows x 5 columns]

# %%
df = pd.read_csv(data_path + 'Students who are Low Income and Have Access to a State-Funded Afterschool Program.csv')
df
# Out:
#     LocationType    Location  TimeFrame DataFormat     Data
# 0          State  California       2013    Percent  0.11832
# 1          State  California       2012    Percent  0.12825
# 2          State  California       2014    Percent  0.12000
# 3          State  California       2016    Percent  0.12000
# 4          State  California       2015    Percent  0.11818
# ..           ...         ...        ...        ...      ...
# 290       County        Yuba       2013    Percent  0.15492
# 291       County        Yuba       2012    Percent  0.12979
# 292       County        Yuba       2014    Percent  0.14000
# 293       County        Yuba       2016    Percent  0.14000
# 294       County        Yuba       2015    Percent  0.14473
#
# [295 rows x 5 columns]

# %%
df = pd.read_csv(data_path + 'Youth in School or Employed.csv')
df
# Out:
#     LocationType    Location              Race  TimeFrame DataFormat   Data
# 0          State  California               All       2014    Percent  0.917
# 1          State  California            Latino       2014    Percent  0.902
# 2          State  California             Asian       2014    Percent  0.959
# 3          State  California  African American       2014    Percent  0.882
# 4          State  California             White       2014    Percent  0.934
# ..           ...         ...               ...        ...        ...    ...
# 703       County        Yuba            Latino       2010    Percent  0.851
# 704       County        Yuba             Asian       2010    Percent    NaN
# 705       County        Yuba  African American       2010    Percent      1
# 706       County        Yuba             White       2010    Percent  0.871
# 707       County        Yuba             Other       2010    Percent   87%*
#
# [708 rows x 6 columns]
